# %%
import os 
os.chdir("..")
import perlib

# %%
pr = perlib.dataPrepration()
data = pr.read_data(path='/Users/ruzgarkanar/Documents/Myprojects/Swagger/perlib_backup/perlib/datasets/ayakkabı_günlük.csv')

# %%
#import pandas as pd
#data = pd.read_csv('/Users/ruzgarkanar/Documents/Myprojects/Swagger/perlib_backup/perlib/datasets/ayakkabı_günlük.csv')
#pr = perlib.dataPrepration(dataFrame=data)

# %%
pr.diff(col='Salecount')
# Out:
# 0        NaN
# 1       2.00
# 2       2.00
# 3       1.00
# 4      -2.00
#         ...
# 1181    0.00
# 1182    4.00
# 1183    5.00
# 1184    0.00
# 1185   -4.00
# Name: Salecount, Length: 1186, dtype: float64

# %%
pr.gauss_Filter(col='Salecount',sigma=3)
# Out:
# 0      18.83
# 1      18.70
# 2      18.39
# 3      17.89
# 4      17.19
#         ...
# 1181   13.95
# 1182   14.56
# 1183   15.13
# 1184   15.57
# 1185   15.82
# Length: 1186, dtype: float64

# %%
pr.moving_average(col='Salecount')
# Out:
# 2      19.00
# 3      20.67
# 4      21.00
# 5      18.67
# 6      15.67
#         ...
# 1181   11.67
# 1182   11.33
# 1183   14.33
# 1184   17.33
# 1185   17.67
# Name: Salecount, Length: 1184, dtype: float64

# %%
pr.exponential_Smoothing(col='Salecount')
# Out:
# 0        NaN
# 1      16.92
# 2      17.00
# 3      19.00
# 4      21.00
#         ...
# 1181   15.00
# 1182   10.00
# 1183   10.00
# 1184   14.00
# 1185   19.00
# Length: 1186, dtype: float64

# %%
pr.rolling_mean_diff(col='Salecount',window=3)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       1.67
# 4       0.33
#         ...
# 1181   -1.67
# 1182   -0.33
# 1183    3.00
# 1184    3.00
# 1185    0.33
# Name: Salecount, Length: 1186, dtype: float64

# %%
pr.circ(dateColumn='Date')
# Out:
#             Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# Date
# 2019-01-01      17.00  338.00 286.00  2019      1    1        2    False
# 2019-01-02      19.00 1174.00 995.00  2019      1    2        3    False
# 2019-01-03      21.00  278.00 236.00  2019      1    3        4    False
# 2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# ...               ...     ...    ...   ...    ...  ...      ...      ...
# 2022-03-27      10.00     NaN    NaN  2022      3   27        7     True
# 2022-03-28      14.00     NaN    NaN  2022      3   28        1    False
# 2022-03-29      19.00     NaN    NaN  2022      3   29        2    False
# 2022-03-30      19.00     NaN    NaN  2022      3   30        3    False
# 2022-03-31      15.00     NaN    NaN  2022      3   31        4    False
#
#             Quarter  Total_cases  ...  Bist100_min  Bist100_volume  CircHourX  \
# ...

# %%
pr.generate_time_lags(col='Salecount',n_lags=3)
# Out:
#            Date  Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# 3    2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 4    2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# 5    2019-01-06      14.00  238.00 202.00  2019      1    6        7     True
# 6    2019-01-07      13.00  280.00 237.00  2019      1    7        1    False
# 7    2019-01-08      15.00  418.00 354.00  2019      1    8        2    False
# ..          ...        ...     ...    ...   ...    ...  ...      ...      ...
# 634  2020-09-26       4.00  124.00 115.00  2020      9   26        6     True
# 635  2020-09-27       4.00  220.00 204.00  2020      9   27        7     True
# 636  2020-09-28       4.00  391.00 337.00  2020      9   28        1    False
# 637  2020-09-29       3.00   20.00  19.00  2020      9   29        2    False
# 638  2020-09-30       3.00  138.00 125.00  2020      9   30        3    False
#
# ...

# %%
pr.generate_time_lags(col='Salecount',firstN=3)
# Out:
#            Date  Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# 3    2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 4    2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# 5    2019-01-06      14.00  238.00 202.00  2019      1    6        7     True
# 6    2019-01-07      13.00  280.00 237.00  2019      1    7        1    False
# 7    2019-01-08      15.00  418.00 354.00  2019      1    8        2    False
# ..          ...        ...     ...    ...   ...    ...  ...      ...      ...
# 634  2020-09-26       4.00  124.00 115.00  2020      9   26        6     True
# 635  2020-09-27       4.00  220.00 204.00  2020      9   27        7     True
# 636  2020-09-28       4.00  391.00 337.00  2020      9   28        1    False
# 637  2020-09-29       3.00   20.00  19.00  2020      9   29        2    False
# 638  2020-09-30       3.00  138.00 125.00  2020      9   30        3    False
#
# ...

# %%
pr.adf_test(columns=['Salecount','Gross'])
# Out:
# Augmented Dickey-Fuller Test: Salecount
# ADF test statistic      -3.78
# p-value                  0.00
# # lags used             17.00
# # observations         299.00
# critical value (1%)     -3.45
# critical value (5%)     -2.87
# critical value (10%)    -2.57
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
# Augmented Dickey-Fuller Test: Gross
# ADF test statistic      -2.14
# p-value                  0.23
# # lags used              8.00
# # observations         308.00
# critical value (1%)     -3.45
# critical value (5%)     -2.87
# critical value (10%)    -2.57
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
pr.date_transform(dateColumn='Date')
# Out:
#             Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# Date
# 2019-01-01      17.00  338.00 286.00  2019      1    1        2    False
# 2019-01-02      19.00 1174.00 995.00  2019      1    2        3    False
# 2019-01-03      21.00  278.00 236.00  2019      1    3        4    False
# 2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# ...               ...     ...    ...   ...    ...  ...      ...      ...
# 2020-09-26       4.00  124.00 115.00  2020      9   26        6     True
# 2020-09-27       4.00  220.00 204.00  2020      9   27        7     True
# 2020-09-28       4.00  391.00 337.00  2020      9   28        1    False
# 2020-09-29       3.00   20.00  19.00  2020      9   29        2    False
# 2020-09-30       3.00  138.00 125.00  2020      9   30        3    False
#
#             Quarter  Total_cases  ...  Euro_max  Euro_min  Bist100_close  \
# ...

# %%
pr.likelihood(targetcol='Salecount',n_features=3)
# Out:
# 2024-03-09 10:11:29.353 | INFO     | perlib.preprocessing.encode:handle:24 - Started encoding categorical features... Method: "AUTO"
# 2024-03-09 10:11:29.355 | DEBUG    | perlib.preprocessing.encode:handle:43 - Encoding to ONEHOT succeeded for feature "Weekend"
# 2024-03-09 10:11:29.357 | DEBUG    | perlib.preprocessing.encode:handle:50 - Encoding skipped for feature "Bist100_volume"
# 2024-03-09 10:11:29.358 | INFO     | perlib.preprocessing.encode:handle:61 - Completed encoding of categorical features in 0.004126 seconds
# AutoProcess process completed in 0.013559 seconds
# X_train shape : (293, 26)
# X_test shape  : (24, 26)
# Y_train shape : (293, 1)
# Y test shape  : (24, 1)
# ['Year', 'USD_min', 'USD_close']

# %%
pr.plb(col='Salecount',period=7,timelag=3)
# Out:
#            Date  Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# 0    2019-01-01      17.00  338.00 286.00  2019      1    1        2    False
# 1    2019-01-02      19.00 1174.00 995.00  2019      1    2        3    False
# 2    2019-01-03      21.00  278.00 236.00  2019      1    3        4    False
# 3    2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 4    2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# ..          ...        ...     ...    ...   ...    ...  ...      ...      ...
# 634  2020-09-26       4.00  124.00 115.00  2020      9   26        6     True
# 635  2020-09-27       4.00  220.00 204.00  2020      9   27        7     True
# 636  2020-09-28       4.00  391.00 337.00  2020      9   28        1    False
# 637  2020-09-29       3.00   20.00  19.00  2020      9   29        2    False
# 638  2020-09-30       3.00  138.00 125.00  2020      9   30        3    False
#
# ...

# %%
pr.replace(to_replace=17,value=1)
# Out:
#            Date  Salecount   Gross    Net  Year  Month  Day  Weekday  Weekend  \
# 0    2019-01-01       1.00  338.00 286.00  2019      1    1        2    False
# 1    2019-01-02      19.00 1174.00 995.00  2019      1    2        3    False
# 2    2019-01-03      21.00  278.00 236.00  2019      1    3        4    False
# 3    2019-01-04      22.00 1045.00 886.00  2019      1    4        5    False
# 4    2019-01-05      20.00  139.00 118.00  2019      1    5        6     True
# ..          ...        ...     ...    ...   ...    ...  ...      ...      ...
# 634  2020-09-26       4.00  124.00 115.00  2020      9   26        6     True
# 635  2020-09-27       4.00  220.00 204.00  2020      9   27        7     True
# 636  2020-09-28       4.00  391.00 337.00  2020      9   28        1    False
# 637  2020-09-29       3.00   20.00  19.00  2020      9   29        2    False
# 638  2020-09-30       3.00  138.00 125.00  2020      9   30        3    False
#
# ...

# %%
pr.duplicated(columns=["Gross"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 634     True
# 635     True
# 636     True
# 637     True
# 638     True
# Length: 317, dtype: bool

# %%
pr.replaceSpaceWithUnderscoreInColumns()
# Out:
#             Date  Salecount    Gross      Net  Year  Month  Day  Weekday  \
# 0     2019-01-01    1926.00  8968.00  8044.00  2019      1    1        2
# 1     2019-01-02    1482.00  6640.00  5953.00  2019      1    2        3
# 2     2019-01-03     826.00  8507.00  7401.00  2019      1    3        4
# 3     2019-01-04     658.00 13660.00 11820.00  2019      1    4        5
# 4     2019-01-05    1228.00 11536.00 10320.00  2019      1    5        6
# ...          ...        ...      ...      ...   ...    ...  ...      ...
# 1181  2022-03-27    1716.00      NaN      NaN  2022      3   27        7
# 1182  2022-03-28    1323.00      NaN      NaN  2022      3   28        1
# 1183  2022-03-29    1201.00      NaN      NaN  2022      3   29        2
# 1184  2022-03-30    1551.00      NaN      NaN  2022      3   30        3
# 1185  2022-03-31    1687.00      NaN      NaN  2022      3   31        4
#
#       Weekend  Quarter  ...  USD_min  Euro_close  Euro_open  Euro_max  \
# ...

# %%
pr.renameColumn(oldColumnName="Salecount",newColumnName="Salecount_1")
# Out:
#             Date  Salecount_1    Gross      Net  Year  Month  Day  Weekday  \
# 0     2019-01-01      1926.00  8968.00  8044.00  2019      1    1        2
# 1     2019-01-02      1482.00  6640.00  5953.00  2019      1    2        3
# 2     2019-01-03       826.00  8507.00  7401.00  2019      1    3        4
# 3     2019-01-04       658.00 13660.00 11820.00  2019      1    4        5
# 4     2019-01-05      1228.00 11536.00 10320.00  2019      1    5        6
# ...          ...          ...      ...      ...   ...    ...  ...      ...
# 1181  2022-03-27      1716.00      NaN      NaN  2022      3   27        7
# 1182  2022-03-28      1323.00      NaN      NaN  2022      3   28        1
# 1183  2022-03-29      1201.00      NaN      NaN  2022      3   29        2
# 1184  2022-03-30      1551.00      NaN      NaN  2022      3   30        3
# 1185  2022-03-31      1687.00      NaN      NaN  2022      3   31        4
#
# ...

# %%
pr.dublicateColumn(column="Gross")
# Out:
#             Date  Salecount    Gross      Net  Year  Month  Day  Weekday  \
# 0     2019-01-01    1926.00  8968.00  8044.00  2019      1    1        2
# 1     2019-01-02    1482.00  6640.00  5953.00  2019      1    2        3
# 2     2019-01-03     826.00  8507.00  7401.00  2019      1    3        4
# 3     2019-01-04     658.00 13660.00 11820.00  2019      1    4        5
# 4     2019-01-05    1228.00 11536.00 10320.00  2019      1    5        6
# ...          ...        ...      ...      ...   ...    ...  ...      ...
# 1181  2022-03-27    1716.00      NaN      NaN  2022      3   27        7
# 1182  2022-03-28    1323.00      NaN      NaN  2022      3   28        1
# 1183  2022-03-29    1201.00      NaN      NaN  2022      3   29        2
# 1184  2022-03-30    1551.00      NaN      NaN  2022      3   30        3
# 1185  2022-03-31    1687.00      NaN      NaN  2022      3   31        4
#
#       Weekend  Quarter  ...  Euro_close  Euro_open  Euro_max  Euro_min  \
# ...

# %%
pr.dublicateScalarColumnWithAction(column="USD_max",action="exp")
# Out:
#             Date  Salecount    Gross      Net  Year  Month  Day  Weekday  \
# 0     2019-01-01    1926.00  8968.00  8044.00  2019      1    1        2
# 1     2019-01-02    1482.00  6640.00  5953.00  2019      1    2        3
# 2     2019-01-03     826.00  8507.00  7401.00  2019      1    3        4
# 3     2019-01-04     658.00 13660.00 11820.00  2019      1    4        5
# 4     2019-01-05    1228.00 11536.00 10320.00  2019      1    5        6
# ...          ...        ...      ...      ...   ...    ...  ...      ...
# 1181  2022-03-27    1716.00      NaN      NaN  2022      3   27        7
# 1182  2022-03-28    1323.00      NaN      NaN  2022      3   28        1
# 1183  2022-03-29    1201.00      NaN      NaN  2022      3   29        2
# 1184  2022-03-30    1551.00      NaN      NaN  2022      3   30        3
# 1185  2022-03-31    1687.00      NaN      NaN  2022      3   31        4
#
#       Weekend  Quarter  ...  Euro_close  Euro_open  Euro_max  Euro_min  \
# ...

# %%
pr.dataFrame["String_value"]="aaaa"
pr.dublicateStringColumnWithAction(column="String_value",action="u")
# Out:
#             Date  Salecount    Gross      Net  Year  Month  Day  Weekday  \
# 0     2019-01-01    1926.00  8968.00  8044.00  2019      1    1        2
# 1     2019-01-02    1482.00  6640.00  5953.00  2019      1    2        3
# 2     2019-01-03     826.00  8507.00  7401.00  2019      1    3        4
# 3     2019-01-04     658.00 13660.00 11820.00  2019      1    4        5
# 4     2019-01-05    1228.00 11536.00 10320.00  2019      1    5        6
# ...          ...        ...      ...      ...   ...    ...  ...      ...
# 1181  2022-03-27    1716.00      NaN      NaN  2022      3   27        7
# 1182  2022-03-28    1323.00      NaN      NaN  2022      3   28        1
# 1183  2022-03-29    1201.00      NaN      NaN  2022      3   29        2
# 1184  2022-03-30    1551.00      NaN      NaN  2022      3   30        3
# 1185  2022-03-31    1687.00      NaN      NaN  2022      3   31        4
#
#       Weekend  Quarter  ...  Euro_open  Euro_max  Euro_min  Bist100_close  \
# ...

# %%
pr.dataFrame = pr.apply(columns=["Salecount", "Net"],function_string="x**2")

# %%
pr.dropColumns(columns=["Weekday", "Quarter"])
# Out:
#             Date  Salecount    Gross          Net  Year  Month  Day  Weekend  \
# 0     2019-01-01 3709476.00  8968.00  64705936.00  2019      1    1    False
# 1     2019-01-02 2196324.00  6640.00  35438209.00  2019      1    2    False
# 2     2019-01-03  682276.00  8507.00  54774801.00  2019      1    3    False
# 3     2019-01-04  432964.00 13660.00 139712400.00  2019      1    4    False
# 4     2019-01-05 1507984.00 11536.00 106502400.00  2019      1    5     True
# ...          ...        ...      ...          ...   ...    ...  ...      ...
# 1181  2022-03-27 2944656.00      NaN          NaN  2022      3   27     True
# 1182  2022-03-28 1750329.00      NaN          NaN  2022      3   28    False
# 1183  2022-03-29 1442401.00      NaN          NaN  2022      3   29    False
# 1184  2022-03-30 2405601.00      NaN          NaN  2022      3   30    False
# 1185  2022-03-31 2845969.00      NaN          NaN  2022      3   31    False
#
# ...

# %%
pr.orderData(columns=["Salecount","Day"],asc=[True,False])
# Out:
#            Date  Salecount   Gross         Net  Year  Month  Day  Weekday  \
# 607  2020-08-30     484.00 6689.00 32455809.00  2020      8   30        7
# 608  2020-08-31     729.00 6251.00 26873856.00  2020      8   31        1
# 606  2020-08-29     841.00 4773.00 16467364.00  2020      8   29        6
# 612  2020-09-04     841.00 6864.00 33698025.00  2020      9    4        5
# 611  2020-09-03     841.00 7473.00 40525956.00  2020      9    3        4
# ..          ...        ...     ...         ...   ...    ...  ...      ...
# 200  2019-07-20 4844401.00     NaN         NaN  2019      7   20        6
# 155  2019-06-05 4901796.00     NaN         NaN  2019      6    5        3
# 817  2021-03-28 4937284.00     NaN         NaN  2021      3   28        7
# 724  2020-12-25 4995225.00     NaN         NaN  2020     12   25        5
# 725  2020-12-26 5193841.00     NaN         NaN  2020     12   26        6
#
#      Weekend  Quarter  ...  Euro_close  Euro_open  Euro_max  Euro_min  \
# ...

# %%
pr.query(expr="Year>2019 &  Net>5000")
# Out:
#            Date  Salecount    Gross          Net  Year  Month  Day  Weekday  \
# 365  2020-01-01  190969.00  8968.00  64705936.00  2020      1    1        3
# 366  2020-01-02   21025.00  6640.00  35438209.00  2020      1    2        4
# 367  2020-01-03   11025.00  8507.00  54774801.00  2020      1    3        5
# 368  2020-01-04   13924.00 13660.00 139712400.00  2020      1    4        6
# 369  2020-01-05   18496.00 11536.00 106502400.00  2020      1    5        7
# ..          ...        ...      ...          ...   ...    ...  ...      ...
# 651  2020-10-13   16900.00  6315.00  28494244.00  2020     10   13        2
# 652  2020-10-14   15876.00  6335.00  29506624.00  2020     10   14        3
# 653  2020-10-15   14400.00  4575.00  14853316.00  2020     10   15        4
# 654  2020-10-16   17161.00  4700.00  15264649.00  2020     10   16        5
# 655  2020-10-17   42849.00  5000.00  17952169.00  2020     10   17        6
#
# ...

# %%
import pandas as pd
data1 = pd.DataFrame({'Day': [1, 2, 3],
         'Name': ['John', 'Alice', 'Bob'],
         'Salary': [50000, 60000, 70000]})
pr.dynamic_join(dataFrame=data1,join_cols=["Day"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 5
#       1 import pandas as pd
#       2 data1 = pd.DataFrame({'Day': [1, 2, 3],
#       3          'Name': ['John', 'Alice', 'Bob'],
#       4          'Salary': [50000, 60000, 70000]})
# ----> 5 pr.dynamic_join(dataFrame=data1,join_cols=["Day"])
#
# TypeError: dataPrepration.dynamic_join() got an unexpected keyword argument 'dataFrame'

# %%
pr.getTimeRelated()
# Out:
# ['Date']

# %%
statistics = pr.getStatistics(columns=['Salecount', 'Gross'])
print("Statistics:")
print(statistics)
# Out:
# ERROR:perlib.preprocessing.preparate: String or NaN value found in column
# Statistics:
# {'Salecount': {'Mean': Salecount   1298988.79
# dtype: float64, 'Std': Salecount   1133084.26
# dtype: float64, 'Median': Salecount   1098304.00
# dtype: float64, 'Kurtosis': Salecount   0.08
# dtype: float64, 'Skewnes': Salecount   0.83
# dtype: float64, 'Q1': Salecount   359105.25
# dtype: float64, 'Q2': Salecount   1098304.00
# dtype: float64, 'Q3': Salecount   1968409.00
# dtype: float64}, 'Gross': {'Mean': Gross   17237.55
# dtype: float64, 'Std': Gross   28383.93
# dtype: float64, 'Median': Gross   8894.00
# dtype: float64, 'Kurtosis': Gross   NaN
# dtype: float64, 'Skewnes': Gross   NaN
# dtype: float64, 'Q1': Gross   NaN
# dtype: float64, 'Q2': Gross   NaN
# dtype: float64, 'Q3': Gross   NaN
# dtype: float64}}

# %%
grouped_df = pr.groupByOperations(group_cols=['Salecount'], agg_cols={'Gross': 'mean'})
print("Grouped DataFrame:")
print(grouped_df)
# Out:
# Grouped DataFrame:
#      Salecount  Gross_mean
# 0       484.00     6689.00
# 1       729.00     6251.00
# 2       841.00     6078.50
# 3       900.00     8590.00
# 4       961.00     9286.00
# ..         ...         ...
# 826 4844401.00         NaN
# 827 4901796.00         NaN
# 828 4937284.00         NaN
# 829 4995225.00         NaN
# 830 5193841.00         NaN
#
# [831 rows x 2 columns]

# %%
filtered_df = pr.filterValue(columns=['Day'], value=25, action='==')
print("Filtered DataFrame:")
print(filtered_df)
# Out:
# Filtered DataFrame:
#             Date  Salecount    Gross           Net  Year  Month  Day  Weekday  \
# 24    2019-01-25  423801.00  8163.00   54567769.00  2019      1   25        5
# 55    2019-02-25 2524921.00      NaN           NaN  2019      2   25        1
# 83    2019-03-25 1411344.00      NaN           NaN  2019      3   25        1
# 114   2019-04-25  400689.00      NaN           NaN  2019      4   25        4
# 144   2019-05-25 1948816.00      NaN           NaN  2019      5   25        6
# 175   2019-06-25  720801.00      NaN           NaN  2019      6   25        2
# 205   2019-07-25 1909924.00      NaN           NaN  2019      7   25        4
# 236   2019-08-25 1865956.00      NaN           NaN  2019      8   25        7
# 267   2019-09-25 1734489.00      NaN           NaN  2019      9   25        3
# 297   2019-10-25 1653796.00      NaN           NaN  2019     10   25        5
# 328   2019-11-25 3326976.00      NaN           NaN  2019     11   25        1
# ...

# %%
null_columns = pr.checkNullColumns(columns=['Salecount', 'Gross'])
print("Null columns:\n", null_columns)
# Out:
# Null columns:
#  Salecount    False
# Gross         True
# dtype: bool

# %%
nulls_in_columns = pr.getNullsInColumns(columns=['Salecount', 'Gross'])
print("Nulls in columns:\n", nulls_in_columns)
# Out:
# Nulls in columns:
#        Salecount  Gross
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# ...         ...    ...
# 1181      False   True
# 1182      False   True
# 1183      False   True
# 1184      False   True
# 1185      False   True
#
# [1186 rows x 2 columns]

# %%
grouped_df = pr.groupByOperations(group_cols=['Salecount'], agg_cols={'Gross': ['sum', 'mean'], 'Day': 'max'})
print("Grouped DataFrame:\n", grouped_df)
# Out:
# Grouped DataFrame:
#       Salecount  Gross_sum  Gross_mean  Day_max
# 0       484.00    6689.00     6689.00       30
# 1       729.00    6251.00     6251.00       31
# 2       841.00   24314.00     6078.50       29
# 3       900.00    8590.00     8590.00        1
# 4       961.00    9286.00     9286.00        5
# ..         ...        ...         ...      ...
# 826 4844401.00       0.00         NaN       20
# 827 4901796.00       0.00         NaN        5
# 828 4937284.00       0.00         NaN       28
# 829 4995225.00       0.00         NaN       25
# 830 5193841.00       0.00         NaN       26
#
# [831 rows x 4 columns]

# %%
cov_matrix = pr.getCov(columns=['Salecount', 'Gross'])
print("Covariance matrix:\n", cov_matrix)
# Out:
# Covariance matrix:
#                   Salecount         Gross
# Salecount 1283879944891.09 7543880967.72
# Gross        7543880967.72  805647484.00

# %%
sample_by_number = pr.getSampleByNumber(n=2, columns=['Salecount', 'Day'])
print("Sample by number:\n", sample_by_number)
# Out:
# Sample by number:
#       Salecount  Day
# 706 1710864.00    7
# 978 1809025.00    5

# %%
sample_with_frac = pr.getSampleWithFrac(frac=0.5, columns=['Salecount', 'Day'])
print("Sample with fraction:\n", sample_with_frac)
# Out:
# Sample with fraction:
#        Salecount  Day
# 557     1681.00   11
# 1171  817216.00   17
# 120   416025.00    1
# 841  4787344.00   21
# 421     8464.00   26
# ...         ...  ...
# 727  1040400.00   28
# 1    2196324.00    2
# 425     8836.00    1
# 615     3025.00    7
# 650    21025.00   12
#
# [593 rows x 2 columns]

# %%
indices = pr.findValues(values=[30, 40], columns=['Day'])
print("Indices of matching values:\n", indices)
# Out:
# Indices of matching values:
#  {'Day': [29, 88, 119, 149, 180, 210, 241, 272, 302, 333, 363, 394, 454, 485, 515, 546, 576, 607, 638, 668, 699, 729, 760, 819, 850, 880, 911, 941, 972, 1003, 1033, 1064, 1094, 1125, 1184]}

# %%
filtered_df = pr.filterValue(columns=['Salecount', 'Day'], value='False', action='equal')
print("Filtered DataFrame:\n", filtered_df)
# Out:
# Filtered DataFrame:
#  Empty DataFrame
# Columns: [Date, Salecount, Gross, Net, Year, Month, Day, Weekday, Weekend, Quarter, Total_cases, New_cases, Total_deaths, New_deaths, USD_close, USD_open, USD_max, USD_min, Euro_close, Euro_open, Euro_max, Euro_min, Bist100_close, Bist100_open, Bist100_max, Bist100_min, Bist100_volume, String_value]
# Index: []
#
# [0 rows x 28 columns]
